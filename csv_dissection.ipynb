# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("test.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
# 3           3        33241   city_115                   0.789        NaN
# 4           4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# ...

# %%
df.shape
# Out:
# (5, 15)

# %%
df=pd.read_csv("test.csv", names=np.arange(0,15))

# %%
df
# Out:
#     0            1         2                       3       4   \
# 0  NaN          NaN       NaN                     NaN     NaN
# 1  0.0  enrollee_id      city  city_development_index  gender
# 2  1.0        29725   city_40                   0.776    Male
# 3  2.0        11561   city_21                   0.624     NaN
# 4  3.0        33241  city_115                   0.789     NaN
# 5  4.0          666  city_162                   0.767    Male
#
#                         5                    6                7   \
# 0                      NaN                  NaN              NaN
# 1      relevent_experience  enrolled_university  education_level
# 2   No relevent experience        no_enrollment         Graduate
# 3   No relevent experience     Full time course         Graduate
# 4   No relevent experience                  NaN         Graduate
# 5  Has relevent experience        no_enrollment          Masters
#
# ...

# %%
df=pd.read_csv("IPL Matches 2008-2020.csv")

# %%
df

# %%
df=pd.read_csv("IPL Matches 2008-2020.csv", usecols=["id", "date"])

# %%
df
# Out:
#           id        date
# 0     335982  2008-04-18
# 1     335983  2008-04-19
# 2     335984  2008-04-19
# 3     335985  2008-04-20
# 4     335986  2008-04-20
# ..       ...         ...
# 811  1216547  2020-09-28
# 812  1237177  2020-11-05
# 813  1237178  2020-11-06
# 814  1237180  2020-11-08
# 815  1237181  2020-11-10
#
# [816 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      816 non-null    int64
#  1   date    816 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 12.9+ KB

# %%
df=pd.read_csv("IPL Matches 2008-2020.csv", usecols=["id", "date"], parse_dates=["date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      816 non-null    int64
#  1   date    816 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 12.9 KB

# %%
df=pd.read_csv("movie_titles_metadata.tsv")

# %%
df
# Out:
#     m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0    m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1    m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2    m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3    m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4    m5\tthe fifth element\t1997\t7.50\t133756\t['a...
# ..                                                 ...
# 611  m612\twatchmen\t2009\t7.80\t135229\t['action' ...
# 612  m613\txxx\t2002\t5.60\t53505\t['action' 'adven...
# 613  m614\tx-men\t2000\t7.40\t122149\t['action' 'sc...
# 614  m615\tyoung frankenstein\t1974\t8.00\t57618\t[...
# 615  m616\tzulu dawn\t1979\t6.40\t1911\t['action' '...
#
# [616 rows x 1 columns]

# %%
df=pd.read_csv("movie_titles_metadata.tsv", sep="\t", names=np.arange(0, 6))

# %%
df
# Out:
#         0                           1     2    3         4  \
# 0      m0  10 things i hate about you  1999  6.9   62847.0
# 1      m1  1492: conquest of paradise  1992  6.2   10421.0
# 2      m2                  15 minutes  2001  6.1   25854.0
# 3      m3       2001: a space odyssey  1968  8.4  163227.0
# 4      m4                     48 hrs.  1982  6.9   22289.0
# ..    ...                         ...   ...  ...       ...
# 612  m612                    watchmen  2009  7.8  135229.0
# 613  m613                         xxx  2002  5.6   53505.0
# 614  m614                       x-men  2000  7.4  122149.0
# 615  m615          young frankenstein  1974  8.0   57618.0
# 616  m616                   zulu dawn  1979  6.4    1911.0
#
#                                                      5
# 0                                 ['comedy' 'romance']
# 1          ['adventure' 'biography' 'drama' 'history']
# 2                ['action' 'crime' 'drama' 'thriller']
# ...

# %%
df=pd.read_csv("movie_titles_metadata.tsv", sep="\t", names=np.arange(0, 6), index_col=0, na_values=[1999, 10421])

# %%
df
# Out:
#                                1     2    3         4  \
# 0
# m0    10 things i hate about you   NaN  6.9   62847.0
# m1    1492: conquest of paradise  1992  6.2       NaN
# m2                    15 minutes  2001  6.1   25854.0
# m3         2001: a space odyssey  1968  8.4  163227.0
# m4                       48 hrs.  1982  6.9   22289.0
# ...                          ...   ...  ...       ...
# m612                    watchmen  2009  7.8  135229.0
# m613                         xxx  2002  5.6   53505.0
# m614                       x-men  2000  7.4  122149.0
# m615          young frankenstein  1974  8.0   57618.0
# m616                   zulu dawn  1979  6.4    1911.0
#
#                                                       5
# 0
# m0                                 ['comedy' 'romance']
# m1          ['adventure' 'biography' 'drama' 'history']
# m2                ['action' 'crime' 'drama' 'thriller']
# m3                     ['adventure' 'mystery' 'sci-fi']
# ...
